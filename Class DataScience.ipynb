# %% [markdown]
# # CLASSES

# %%
class Car:
    
    #arrtibutes => data members
        year = 2019 
        mpg = 22
        speed = 100
        
    #methods ---->>> >> > member functions
        def accelerate(self):
            return self.speed
        
        def brake(self):
            return self.speed
        
    #SELF ------>>> >> > self will we load object
    #Self is instance of class
    #In Self oject name will be passed automatically
    # self.speed ---->>> >> > car1.speed() 

car1 = Car()

# %%
#Object or instance
#IF i will not create object or instance, It will not take the memory.
car1 = Car()
car1.accelerate()
# Out:
# 100

# %%
#when you are trying to access variable(attribute in class) 
#noo need of curly braces car1.speed 
#But for function(called method in a class)
#Need to access it with braces
print(car1.speed)
car1.accelerate()
# Out:
# 100
# 100

# %%
#if __name__=="__main__":
#It checks if the function -->>> >> > main is present or not.
#If it is present then it will be printed.

# %%
class Myclass:
    k = 123
    d = 19.7
    def testf(self):
        print("This is my first class")
        
def main():
    #creating object/instance
    #calling attribute with member function
    print(m.k)
    print(m.d) 
    m = Myclass()

# %%
class car:
    
    def __init__(self,car,model,kmp):
        print("Initialized")
        self.car = car
        self.kmp = kmp
        
    def acceleration(self):
#         self.car = car
#         self.kmp = kmp
          print("car %s and speed %d"%(self.car,self.kmp))
        
def main():
    print("main")
    carInfo = car("Mercadese","AMG",300)
    carInfo.acceleration()
    
        
if __name__=="__main__":
    main()
# Out:
# main
# Initialized
# car Mercadese and speed 300

# %%
dic1 = {"name1":"Tanbir Singh","name2":"aman"}
dic1.keys()
# Out:
# dict_keys(['name1', 'name2'])

# %%
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> update
# No Python documentation found for 'update'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help> update
# No Python documentation found for 'update'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# ...

# %%
dic1.update({'singh':'nam'})
dic1
# Out:
# {'name1': 'Tanbir Singh', 'name2': 'aman', 'singh': 'nam'}

# %%
print("hi","e",sep = ":")
# Out:
# hi:e

# %%
class company:
    #class variable
    company_revenue = 800000
    
    def __init__(self,name,id,no_of_emp):
        self.name = name
        self.id = id
        self.no_of_emp = no_of_emp

# %%
# Creating object/Instance
comp = company("Tanbir Singh",107701,99)
print(comp.name)
print(comp.id)

#accesssing class variable

company.company_revenue

#company_revenue us the constructor/variable of the Class 
#It can only be accessed by class
# Out:
# Tanbir Singh
# 107701
# 800000

# %%
#Simple class for cars
class car:
    #Construcator to initalize
    def __init__(self,color):
        self.color = color
        
    def disp(self):
        print("This is a",self.color)
        
def main():
    c=car("Red")
    print(c.disp())
    
if __name__=="__main__":
    main()
# Out:
# This is a Red
# None

# %%
class Employee:
    def __init__(self,name,age):
        print("Initialized method called")
        self.name = name
        self.age = age
        
    def getdata(self,name,age):
        print("getdata method called")
        self.name = name
        self.age = age
        
    def displaydata(self):
        print("Hello ",self.name,self.age)

# %%
def main():
    E = Employee("Tanbir singh",25)
    E.displaydata()

if __name__=="__main__":
    main()
# Out:
# Initialized method called
# Hello  Tanbir singh 25

# %%
class Player:
    def __init__(self,name,age,sport):
        print("Initialized data for Player")
        self.name = name
        self.age = age
        self.sport = sport
        
    def getdata(self,name,age,sport):
        print("Getting data for players")
        self.name = name
        self.age = age
        self.sport = sport
        
    def displaydata(self):
        print("Display Data of player",self.name,self.age,self.sport)
        
def main():
    print("Printing main and creating object/instance")
    p1 = Player("Tanbir singh",25,"Soccor")
    p1.displaydata()
    
if __name__=="__main__":
    main()
# Out:
# Printing main and creating object/instance
# Initialized data for Player
# Display Data of player Tanbir singh 25 Soccor

# %%
#class 1 
#class 2     #all these classes together are called MODULE
#class 3

# %% [markdown]
# # MODULES in Python

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\tanbsing',
#  'C:\\Users\\tanbsing\\Anaconda3\\python38.zip',
#  'C:\\Users\\tanbsing\\Anaconda3\\DLLs',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib',
#  'C:\\Users\\tanbsing\\Anaconda3',
#  '',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\tanbsing\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\tanbsing\\.ipython']

# %%
import os 
os.path
# Out:
# <module 'ntpath' from 'C:\\Users\\tanbsing\\Anaconda3\\lib\\ntpath.py'>

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
int(math.sqrt(49))
# Out:
# 7

# %%
# Power function 2^3 = 8
math.pow(2,3)
# Out:
# 8.0

# %% [markdown]
# ### Import with Renaming

# %%
import math as m
m.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### Import with Statements

# %%
from math import pi
pi
# Out:
# 3.141592653589793

# %%
import datetime

dt=datetime.date.today()
dt
# Out:
# datetime.date(2021, 12, 5)

# %%
dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-88fbb34a0e8d> in <module>
# ----> 1 dt.year
#
# NameError: name 'dt' is not defined

# %%
class Music:
    def __init__(self,singer,song,label):
        self.singer = singer
        self.song = song
        self.label = label
    
    def Artist(self):
        print(f"Name : {self.singer}\t|\tSong : {self.song}\t|\tLabel : {self.label}")
    
    def Album(self,)
def main():
    musicInfo = Music("Micky Singh","S O R R Y","YTL")
    print("-----"*17)
    musicInfo.Artist()
    print("-----"*17)
    
if __name__=="__main__":
    main()
# Out:
# -------------------------------------------------------------------------------------
# Name : Micky Singh	|	Song : S O R R Y	|	Label : YTL
# -------------------------------------------------------------------------------------

# %%
import datetime
dt = datetime.datetime.today()
dt.time()
# Out:
# datetime.time(15, 56, 10, 502069)

# %%
help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/datetime
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-78-b717138f67ae> in <module>
# ----> 1 import music
#
# ModuleNotFoundError: No module named 'music'
